# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyCzpTa1xlDhrSV7KONTZUcei7JFtl62A9o"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="Iot0eF6EoNA",
    maxResults=1000
)
response = request.execute()

comments = []

for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at', 'like_count', 'text'])
df.to_csv('comments.csv')
df.head(1000)
# Out:
#                   author          published_at            updated_at  \
# 0          Indah Gugatha  2023-11-23T08:12:08Z  2023-11-23T08:12:08Z
# 1                 ZXDON!  2023-11-20T10:11:10Z  2023-11-20T10:11:26Z
# 2                   RV ツ  2023-11-18T19:05:13Z  2023-11-18T19:05:13Z
# 3                fighter  2023-11-18T17:59:30Z  2023-11-18T17:59:30Z
# 4         Pushkar Pashte  2023-11-16T05:04:25Z  2023-11-16T05:04:56Z
# ..                   ...                   ...                   ...
# 95       Sonu Kumar bage  2023-07-18T15:00:25Z  2023-07-18T15:00:25Z
# 96         Akash Sridhar  2023-07-18T12:33:58Z  2023-07-18T12:33:58Z
# 97        Parvathi .M. S  2023-07-17T08:29:42Z  2023-07-17T08:29:42Z
# 98  rifayudeen nehrudeen  2023-07-16T17:11:16Z  2023-07-16T17:11:16Z
# 99   FAMOUS PLACE VLOGS   2023-07-16T08:25:11Z  2023-11-03T23:40:01Z
#
#     like_count                                               text
# 0            0                 What&#39;s wrong whit this video??
# 1            2  I&#39;m here in 2023 to see the dislikes but s...
# 2            2  As a premium User Dislikes are 1.4cr... Thank ...
# 3            1                      14M dislikes, keep it rolling
# 4            3  Fun Fact :- This Movie Is The Reason Behind Yo...
# ..         ...                                                ...
# 95           1  Bhai ye record koi na tor paya isliye  humne v...
# 96           2  For Those Who Disliked The Trailer Once It Rel...
# 97           2  2nd most disliked video on youtube<br>What the...
# 98           1                                              Rip👁️
# 99           2  Those 81 million views were never to be forgot...
#
# [100 rows x 5 columns]

# %%
# !pip install pandas nltk
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer

# Download NLTK resources
import nltk
nltk.download('vader_lexicon')

def analyze_sentiment(comment):
    sid = SentimentIntensityAnalyzer()
    sentiment_scores = sid.polarity_scores(comment)

    if sentiment_scores['compound'] >= 0.05:
        return 'positive'
    elif sentiment_scores['compound'] <= -0.05:
        return 'negative'
    else:
        return 'neutral'

# Load the CSV file into a DataFrame
file_path = 'comments.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)

# Apply sentiment analysis to the 'text' column
df['sentiment'] = df['text'].apply(analyze_sentiment)

# Save the updated DataFrame to a new CSV file
output_file_path = 'output_file.csv'  # Replace with your desired output file path
df.to_csv(output_file_path, index=False)

# Display the updated DataFrame
print(df.head(100))
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#     Unnamed: 0                author          published_at  \
# 0            0         Indah Gugatha  2023-11-23T08:12:08Z
# 1            1                ZXDON!  2023-11-20T10:11:10Z
# 2            2                  RV ツ  2023-11-18T19:05:13Z
# 3            3               fighter  2023-11-18T17:59:30Z
# 4            4        Pushkar Pashte  2023-11-16T05:04:25Z
# ..         ...                   ...                   ...
# 95          95       Sonu Kumar bage  2023-07-18T15:00:25Z
# 96          96         Akash Sridhar  2023-07-18T12:33:58Z
# 97          97        Parvathi .M. S  2023-07-17T08:29:42Z
# 98          98  rifayudeen nehrudeen  2023-07-16T17:11:16Z
# 99          99   FAMOUS PLACE VLOGS   2023-07-16T08:25:11Z
#
#               updated_at  like_count  \
# 0   2023-11-23T08:12:08Z           0
# 1   2023-11-20T10:11:26Z           2
# 2   2023-11-18T19:05:13Z           2
# 3   2023-11-18T17:59:30Z           1
# 4   2023-11-16T05:04:56Z           3
# ..                   ...         ...
# 95  2023-07-18T15:00:25Z           1
# 96  2023-07-18T12:33:58Z           2
# 97  2023-07-17T08:29:42Z           2
# 98  2023-07-16T17:11:16Z           1
# 99  2023-11-03T23:40:01Z           2
#
#                                                  text sentiment
# 0                  What&#39;s wrong whit this video??  negative
# 1   I&#39;m here in 2023 to see the dislikes but s...  negative
# 2   As a premium User Dislikes are 1.4cr... Thank ...  negative
# 3                       14M dislikes, keep it rolling  negative
# 4   Fun Fact :- This Movie Is The Reason Behind Yo...  positive
# ..                                                ...       ...
# 95  Bhai ye record koi na tor paya isliye  humne v...  negative
# 96  For Those Who Disliked The Trailer Once It Rel...  negative
# 97  2nd most disliked video on youtube<br>What the...  negative
# 98                                              Rip👁️   neutral
# 99  Those 81 million views were never to be forgot...  positive
#
# [100 rows x 7 columns]
